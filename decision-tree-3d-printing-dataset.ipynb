# %% [markdown]
# <a href="https://www.kaggle.com/code/aniruddhasarkar/decision-tree-3d-printing-dataset?scriptVersionId=136865400" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h2 align="center"> Why This Dataset?? 🛠 : </h2>
#
# I have worked for [Fablab-KUET](https://www2.kuet.ac.bd/fablab/person/aniruddha-sarkar/) for more then 3 years. Where my duty was to help the students to fabricate their mechatronics projects by using 3D printer, LASER Cutter and CNC milling machine. I used CURA Ultimaker most of the time until the PRUSA arrived. So, when I discovered this dataset, I found that the labels and features deal with the filaments(ABS, PLA), Fan speed, Temparture, infill and so on. I could literallty visualize what the dataset is trying to say. So, I couldn't resist my temptation to play with it. The dataset is small but infront of my will it is big enough!
#
# <div style="text-align:center"><img src="https://github.com/Aniruddha120/Aniruddha120/assets/34673269/5e3b2165-729b-4a76-abdd-84c7e8cb2f17" /></div>

# %% [markdown]
# # Previous Investigation
#
# I found that a [Kaggler used linear regreesion](https://www.kaggle.com/code/ashishpaul17/linear-regression-study-on-the-3d-printing-dataset) to predicit certain features and the accuracy was good. But this time I am adopting other models even if the accuracy is compromised. For the sake of research. In future I wish to apply some other models also.

# %% [markdown]
# # Importing Libraries for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading the dataset.

# %%
df = pd.read_csv('../input/3dprinter/data.csv')

# %% [markdown]
# # Investigating the number of features and rows

# %%
df.shape

# %% [markdown]
# The dataset is small, and the accuracy might be compromised

# %%
df.head(10)

# %% [markdown]
# # One Hot Encoding the Catagorical Features

# %%
df['infill_pattern'].replace(['grid','honeycomb'], [0,1], inplace = True)
df['material'].replace(['abs','pla'], [0,1], inplace = True)

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (20,7))
sns.heatmap(df.corr(), annot = True, )

# %%
X = df.drop(['roughness','tension_strenght','elongation'], axis = 1)
y = df['roughness']

# %%
X.head()

# %% [markdown]
# # So the EDA Ends
#
# Now we can test various models on this dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %% [markdown]
# # Cross Validation Score:
#
# For cross validation, I am adopting Linear Regression, Lasso, ElasticNet ( Just wanted to see so..), DecisionTreeRegressor and Ridge

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=120)

# %% [markdown]
# Result of Linear Regression

# %%
cross_val_score(LinearRegression(), X, y, cv=cv)

# %% [markdown]
# Result of Lasso

# %%
cross_val_score(Lasso(), X, y, cv=cv)

# %% [markdown]
# Result of Decision Tree Regressor

# %%
cross_val_score(DecisionTreeRegressor(), X, y, cv=cv)

# %% [markdown]
# Result of Elastic net

# %%
cross_val_score(ElasticNet(), X, y, cv=cv)

# %% [markdown]
# Result of Ridge

# %%
cross_val_score(Ridge(), X, y, cv=cv)

# %% [markdown]
# # Summary
#
# So far with the existing wrangled data we can catagorise :
# Linear Regression > Decision Tree> Lasso

# %% [markdown]
# # Going With Decision Tree

# %%
dreg = DecisionTreeRegressor()
dreg.fit(X_train,y_train)
dreg.score(X_test,y_test)

# %% [markdown]
# # Comments:
#
# The features can be engineered much further to achieve the desired accuracy. My next goal will be to improve the accuracy and apply deeplearning model in another notebook. Don't forget to drop your comments!
